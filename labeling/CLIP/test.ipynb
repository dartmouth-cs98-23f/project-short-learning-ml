# %%
from clip import CLIP

from IPython.display import display, Markdown

# %% [markdown]
# ## Initialize the Model

# %%
# create model
model = CLIP()

display(Markdown('### Model Categories:'))

for category in model.categories:
  display(Markdown(f' - {category}'))
# Out:
# ### Model Categories:
#  - machine learning
#  - computer graphics
#  - web development
#  - algebra
#  - calculus
#  - statistics
#  - economics
#  - marketing
#  - commerce
#  - kinematics
#  - electromagnetism
#  - thermodynamics
#  - geology
#  - cartography
#  - meteorology
#  - genetics
#  - biochemistry
#  - ecology

# %% [markdown]
# ## Process 3B1B Video

# %%
# id = "_XdD-TQseU4"  # MKBHD
id = "Ilg3gGewQ5U"   # 3B1B
res = model.process(id)
res.head(10)
# Out:
# Decodes: 10
# Decodes: 20
# Decodes: 30
# Decodes: 40
# Decodes: 50
# Decodes: 60
# Decodes: 70
# Decodes: 80
# Decodes: 90
# Decodes: 100
# Decodes: 110
# Decodes: 120
#                                               categories  machine learning  \
# frame
# 0         [computer graphics, algebra, electromagnetism]          0.014166
# 1           [electromagnetism, thermodynamics, calculus]          0.018727
# 2             [web development, marketing, biochemistry]          0.024134
# 3             [web development, biochemistry, marketing]          0.027729
# 4             [web development, biochemistry, marketing]          0.027836
# 5      [machine learning, kinematics, computer graphics]          0.635110
# 6      [machine learning, kinematics, computer graphics]          0.648437
# 7      [machine learning, kinematics, computer graphics]          0.703734
# 8      [machine learning, kinematics, computer graphics]          0.528253
# 9      [machine learning, kinematics, computer graphics]          0.588804
#
#        computer graphics  web development   algebra  calculus  statistics  \
# frame
# 0               0.304691         0.047511  0.114997  0.044637    0.023144
# 1               0.061013         0.011481  0.039391  0.091737    0.017987
# 2               0.093693         0.437583  0.025596  0.033324    0.017045
# 3               0.092341         0.418527  0.038002  0.041205    0.029304
# 4               0.095753         0.425064  0.037393  0.040566    0.028267
# 5               0.077962         0.001798  0.039416  0.022990    0.049433
# 6               0.081538         0.002100  0.050065  0.023221    0.030499
# 7               0.082597         0.001875  0.023682  0.014464    0.014780
# 8               0.099092         0.001036  0.082243  0.039658    0.028278
# 9               0.077393         0.000635  0.051724  0.033203    0.028163
#
#        economics  marketing  commerce  kinematics  electromagnetism  \
# frame
# 0       0.014404   0.006084  0.070687    0.056022          0.089348
# 1       0.005036   0.001965  0.009833    0.050240          0.420191
# 2       0.002791   0.151880  0.002412    0.000808          0.017636
# 3       0.004603   0.118019  0.003309    0.000820          0.034605
# 4       0.004512   0.114615  0.003269    0.000807          0.033961
# 5       0.001373   0.000115  0.000694    0.113288          0.031016
# 6       0.001415   0.000122  0.000904    0.105120          0.034707
# 7       0.000661   0.000106  0.000822    0.090446          0.045814
# 8       0.002086   0.000101  0.001043    0.142617          0.036637
# 9       0.001714   0.000097  0.000525    0.121445          0.057014
#
#        thermodynamics   geology  cartography  meteorology  genetics  \
# frame
# 0            0.051373  0.007123     0.014427     0.048450  0.007722
# 1            0.185912  0.005113     0.017363     0.008428  0.016021
# 2            0.004040  0.002378     0.012592     0.009788  0.006026
# 3            0.005803  0.003391     0.014924     0.012243  0.007663
# 4            0.005719  0.003280     0.014719     0.012044  0.007380
# 5            0.015629  0.000138     0.001334     0.000838  0.004373
# 6            0.013458  0.000094     0.001139     0.000990  0.003103
# 7            0.014343  0.000059     0.001182     0.000684  0.002141
# 8            0.028200  0.000079     0.001863     0.000868  0.004471
# 9            0.027543  0.000106     0.000858     0.000788  0.004114
#
#        biochemistry   ecology
# frame
# 0          0.051393  0.033822
# 1          0.014445  0.025118
# 2          0.140099  0.018173
# 3          0.125572  0.021939
# 4          0.123374  0.021440
# 5          0.003359  0.001134
# 6          0.001954  0.001133
# 7          0.001562  0.001047
# 8          0.002223  0.001251
# 9          0.005017  0.000856

# %% [markdown]
# ## Process Fireship Video

# %%
id = "lHZwlzOUOZ4"  # fireship
res = model.process(id)
res.head(10)
# Out:
# Decodes: 130
# Decodes: 140
# Decodes: 150
# Decodes: 160
# Decodes: 170
# Decodes: 180
# Decodes: 190
# Decodes: 200
# Decodes: 210
# Decodes: 220
# Decodes: 230
# Decodes: 240
#                                               categories  machine learning  \
# frame
# 0                   [web development, commerce, algebra]          0.012878
# 1         [web development, marketing, machine learning]          0.110795
# 2          [commerce, computer graphics, thermodynamics]          0.029501
# 3      [thermodynamics, computer graphics, web develo...          0.046891
# 4                 [computer graphics, commerce, algebra]          0.006808
# 5       [computer graphics, thermodynamics, cartography]          0.004591
# 6        [thermodynamics, electromagnetism, meteorology]          0.054590
# 7      [web development, machine learning, thermodyna...          0.083592
# 8                  [economics, calculus, thermodynamics]          0.022938
# 9           [economics, thermodynamics, web development]          0.068543
#
#        computer graphics  web development   algebra  calculus  statistics  \
# frame
# 0               0.081896         0.236559  0.108307  0.053717    0.057686
# 1               0.098506         0.256520  0.068159  0.067604    0.073006
# 2               0.234102         0.068085  0.011806  0.057188    0.010177
# 3               0.130594         0.101849  0.084130  0.077731    0.023590
# 4               0.430264         0.049749  0.079755  0.052443    0.031548
# 5               0.137361         0.101251  0.033139  0.057446    0.035287
# 6               0.003214         0.025814  0.040992  0.070496    0.035443
# 7               0.014189         0.763427  0.008392  0.018145    0.021269
# 8               0.014635         0.043826  0.113739  0.176816    0.046881
# 9               0.013638         0.155769  0.059331  0.053113    0.045077
#
#        economics  marketing  commerce  kinematics  electromagnetism  \
# frame
# 0       0.023151   0.057525  0.139425    0.036766          0.009919
# 1       0.008395   0.126717  0.064155    0.008129          0.013936
# 2       0.010005   0.015517  0.286701    0.078224          0.051576
# 3       0.036623   0.066729  0.026468    0.064991          0.027746
# 4       0.015517   0.020178  0.167461    0.034040          0.029645
# 5       0.042043   0.030695  0.099768    0.023734          0.063348
# 6       0.060725   0.011668  0.012557    0.041974          0.180241
# 7       0.023713   0.009002  0.005228    0.003178          0.001279
# 8       0.211620   0.004982  0.056019    0.023978          0.045675
# 9       0.273598   0.008214  0.056966    0.008900          0.029133
#
#        thermodynamics   geology  cartography  meteorology  genetics  \
# frame
# 0            0.091150  0.009018     0.012340     0.014746  0.007523
# 1            0.065379  0.002523     0.009092     0.008323  0.002779
# 2            0.096931  0.000340     0.012180     0.018868  0.005092
# 3            0.154826  0.005426     0.007353     0.046958  0.022435
# 4            0.017138  0.002873     0.023173     0.007424  0.021434
# 5            0.127439  0.001169     0.116240     0.025096  0.023023
# 6            0.234182  0.005496     0.001678     0.158775  0.003426
# 7            0.029940  0.005132     0.000882     0.005118  0.001963
# 8            0.166220  0.009481     0.002516     0.036777  0.003082
# 9            0.162697  0.008564     0.002041     0.029302  0.003163
#
#        biochemistry   ecology
# frame
# 0          0.022129  0.025262
# 1          0.010762  0.005221
# 2          0.006734  0.006972
# 3          0.065914  0.009746
# 4          0.002936  0.007615
# 5          0.013783  0.064589
# 6          0.018696  0.040031
# 7          0.001749  0.003801
# 8          0.004243  0.016570
# 9          0.006630  0.015320

# %% [markdown]
# ## Process Wendover Video

# %%
id = "8xzINLykprA"  # wendover
res = model.process(id)
res.head(10)
# Out:
# Decodes: 250
# Decodes: 260
# Decodes: 270
# Decodes: 280
# Decodes: 290
# Decodes: 300
# Decodes: 310
# Decodes: 320
# Decodes: 330
# Decodes: 340
# Decodes: 350
# Decodes: 360
#                                               categories  machine learning  \
# frame
# 0         [computer graphics, algebra, electromagnetism]          0.014166
# 1      [computer graphics, web development, cartography]          0.019741
# 2      [machine learning, web development, computer g...          0.340495
# 3      [machine learning, web development, computer g...          0.399529
# 4      [machine learning, computer graphics, thermody...          0.425977
# 5      [machine learning, computer graphics, web deve...          0.605698
# 6      [machine learning, computer graphics, web deve...          0.580393
# 7      [machine learning, computer graphics, web deve...          0.363997
# 8      [web development, computer graphics, machine l...          0.152911
# 9      [machine learning, web development, computer g...          0.397971
#
#        computer graphics  web development   algebra  calculus  statistics  \
# frame
# 0               0.304691         0.047511  0.114997  0.044637    0.023144
# 1               0.430353         0.113132  0.030301  0.067889    0.016535
# 2               0.183242         0.217519  0.012974  0.006463    0.003752
# 3               0.144974         0.238090  0.009865  0.006318    0.007281
# 4               0.166820         0.098123  0.012583  0.008405    0.006294
# 5               0.113232         0.087065  0.007202  0.003538    0.004311
# 6               0.114897         0.109781  0.007625  0.003808    0.004313
# 7               0.201727         0.134110  0.013660  0.007644    0.009230
# 8               0.154722         0.424003  0.014171  0.008633    0.017019
# 9               0.136952         0.211671  0.007473  0.004041    0.013243
#
#        economics  marketing  commerce  kinematics  electromagnetism  \
# frame
# 0       0.014404   0.006084  0.070687    0.056022          0.089348
# 1       0.004315   0.002975  0.023254    0.080856          0.031815
# 2       0.004773   0.004816  0.027466    0.052325          0.010439
# 3       0.015102   0.009027  0.037125    0.027886          0.005327
# 4       0.013972   0.006666  0.029716    0.028753          0.005898
# 5       0.009408   0.006062  0.018981    0.017978          0.003987
# 6       0.009392   0.007661  0.029567    0.023420          0.006645
# 7       0.011080   0.004106  0.035357    0.075257          0.008215
# 8       0.016705   0.010643  0.044910    0.049063          0.004809
# 9       0.005893   0.007163  0.031075    0.085239          0.003617
#
#        thermodynamics   geology  cartography  meteorology  genetics  \
# frame
# 0            0.051373  0.007123     0.014427     0.048450  0.007722
# 1            0.033906  0.005669     0.102066     0.013945  0.003571
# 2            0.066054  0.001517     0.056016     0.003418  0.003413
# 3            0.049268  0.000918     0.032140     0.005024  0.006657
# 4            0.135773  0.001444     0.034912     0.010370  0.004850
# 5            0.072517  0.000914     0.026311     0.009459  0.005522
# 6            0.054579  0.000793     0.026718     0.008558  0.003640
# 7            0.063175  0.001043     0.051685     0.005892  0.006584
# 8            0.026530  0.000973     0.056078     0.004274  0.006847
# 9            0.030216  0.001002     0.033233     0.006560  0.006508
#
#        biochemistry   ecology
# frame
# 0          0.051393  0.033822
# 1          0.002729  0.016949
# 2          0.001688  0.003631
# 3          0.001376  0.004092
# 4          0.003248  0.006195
# 5          0.002050  0.005767
# 6          0.002725  0.005486
# 7          0.001948  0.005289
# 8          0.001811  0.005897
# 9          0.003668  0.014476
