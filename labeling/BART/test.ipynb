# %%
from bart import BART

from IPython.display import display, Markdown

# %% [markdown]
# ## Initialize the Model

# %%
# create model
model = BART()

display(Markdown('### Model Categories:'))

for category in model.categories:
  display(Markdown(f' - {category}'))
# Out:
# ### Model Categories:
#  - machine learning
#  - computer graphics
#  - web development
#  - algebra
#  - calculus
#  - statistics
#  - economics
#  - marketing
#  - commerce
#  - kinematics
#  - electromagnetism
#  - thermodynamics
#  - geology
#  - cartography
#  - meteorology
#  - genetics
#  - biochemistry
#  - ecology

# %% [markdown]
# ## Process 3B1B Video

# %%
# id = "_XdD-TQseU4"  # MKBHD
id = "Ilg3gGewQ5U"   # 3B1B
res = model.process(id)
res.head(10)
# Out:
# Decodes: 10
# Decodes: 20
# Decodes: 30
# Decodes: 40
# Decodes: 50
# Decodes: 60
#                                                categories  \
# second
# 0                   [machine learning, genetics, ecology]
# 5        [machine learning, computer graphics, marketing]
# 10              [machine learning, marketing, kinematics]
# 15                 [machine learning, marketing, algebra]
# 20                         [calculus, algebra, marketing]
# 25                  [machine learning, calculus, algebra]
# 30              [machine learning, marketing, kinematics]
# 35        [machine learning, marketing, electromagnetism]
# 40      [machine learning, computer graphics, web deve...
# 45             [machine learning, statistics, kinematics]
#
#                                                transcript  machine learning  \
# second
# 0                         Here we tackle backpropagation,          0.770241
# 5       Here we tackle backpropagation, the core algor...          0.627643
# 10      the core algorithm behind how neural networks ...          0.794947
# 15      the first thing I'll do is an intuitive walkth...          0.520056
# 20      without any reference to the formulas, Then fo...          0.105093
# 25      the next video goes into the calculus underlyi...          0.754098
# 30      or if you're just jumping in with the appropri...          0.738837
# 35      Here we're doing the classic example of recogn...          0.334974
# 40      whose pixel values get fed into the first laye...          0.724369
# 45      and an output layer of 10 neurons, indicating ...          0.690759
#
#         computer graphics  web development   algebra  calculus  statistics  \
# second
# 0                0.422197         0.047068  0.236872  0.141980    0.244502
# 5                0.055564         0.019603  0.014419  0.010485    0.016701
# 10               0.028672         0.019325  0.027429  0.005168    0.005443
# 15               0.074506         0.086806  0.194374  0.116195    0.014098
# 20               0.026586         0.036203  0.301255  0.476862    0.003330
# 25               0.061831         0.156554  0.529258  0.641731    0.015832
# 30               0.066508         0.091914  0.030052  0.020311    0.084054
# 35               0.028782         0.014919  0.017903  0.012450    0.015293
# 40               0.590216         0.276762  0.071566  0.082414    0.070939
# 45               0.336731         0.225638  0.170565  0.222749    0.411877
#
#         economics  marketing  commerce  kinematics  electromagnetism  \
# second
# 0        0.154529   0.288450  0.039872    0.161526          0.053019
# 5        0.003791   0.051286  0.016832    0.016867          0.005305
# 10       0.008520   0.061335  0.018219    0.052840          0.004282
# 15       0.031490   0.231672  0.047363    0.125801          0.110190
# 20       0.048525   0.141564  0.010616    0.037063          0.046326
# 25       0.179849   0.294302  0.020631    0.306912          0.040714
# 30       0.043474   0.208479  0.022455    0.146725          0.017084
# 35       0.006567   0.071294  0.000464    0.034504          0.056474
# 40       0.080532   0.182748  0.008043    0.137881          0.167342
# 45       0.170120   0.273510  0.088989    0.368889          0.141588
#
#         thermodynamics   geology  cartography  meteorology  genetics  \
# second
# 0             0.359186  0.525253     0.056475     0.302239  0.632426
# 5             0.001429  0.003647     0.011623     0.002886  0.003298
# 10            0.000713  0.006527     0.012418     0.001068  0.001191
# 15            0.064374  0.033841     0.012712     0.014984  0.001712
# 20            0.013736  0.012989     0.005444     0.008529  0.002453
# 25            0.008163  0.005752     0.018453     0.005884  0.018874
# 30            0.009066  0.015580     0.017117     0.020059  0.013169
# 35            0.004202  0.002901     0.010507     0.004445  0.020728
# 40            0.013572  0.037025     0.079042     0.023459  0.057492
# 45            0.041238  0.127105     0.162113     0.019641  0.025303
#
#         biochemistry   ecology
# second
# 0           0.352895  0.573010
# 5           0.004072  0.008149
# 10          0.001733  0.013870
# 15          0.024657  0.021049
# 20          0.026628  0.010523
# 25          0.020125  0.039981
# 30          0.029953  0.081538
# 35          0.004177  0.008296
# 40          0.032371  0.065052
# 45          0.090173  0.147042

# %% [markdown]
# ## Process Fireship Video

# %%
id = "lHZwlzOUOZ4"  # fireship
res = model.process(id)
res.head(10)
# Out:
# Decodes: 70
# Decodes: 80
# Decodes: 90
# Decodes: 100
#                                                categories  \
# second
# 0          [marketing, web development, machine learning]
# 5         [web development, computer graphics, marketing]
# 10        [web development, marketing, computer graphics]
# 15        [web development, marketing, computer graphics]
# 20              [web development, statistics, kinematics]
# 25        [web development, marketing, computer graphics]
# 30      [electromagnetism, computer graphics, kinematics]
# 35                     [marketing, statistics, economics]
# 40                    [statistics, marketing, kinematics]
# 45             [marketing, statistics, computer graphics]
#
#                                                transcript  machine learning  \
# second
# 0       it is January 16 2023 and you're watching the ...          0.287435
# 5       it is January 16 2023 and you're watching the ...          0.093162
# 10      worst way to do CSS except for all the other w...          0.059130
# 15      war erupted yesterday after somebody had the a...          0.182976
# 20      defended this code while the unified CSS funda...          0.116092
# 25      dehumanizing things about it like it's not eve...          0.109440
# 30      feelings from hearing mild criticisms about te...          0.249405
# 35      truly horrific I decided to run a poll to see ...          0.136414
# 40      most have never tried it 4 out of five people ...          0.307531
# 45      may not be a good fit for every project in thi...          0.188318
#
#         computer graphics  web development   algebra  calculus  statistics  \
# second
# 0                0.168126         0.310662  0.021376  0.034530    0.275652
# 5                0.298795         0.773452  0.007111  0.010272    0.132494
# 10               0.338759         0.724057  0.041681  0.059404    0.171044
# 15               0.456298         0.569370  0.146994  0.093648    0.179468
# 20               0.094611         0.484917  0.038515  0.047637    0.219439
# 25               0.422702         0.526702  0.013733  0.003429    0.145901
# 30               0.322569         0.223889  0.047901  0.038561    0.066371
# 35               0.111020         0.098849  0.072566  0.170039    0.487487
# 40               0.413190         0.299174  0.208290  0.172043    0.795439
# 45               0.276473         0.201491  0.085157  0.036617    0.342862
#
#         economics  marketing  commerce  kinematics  electromagnetism  \
# second
# 0        0.212926   0.385499  0.090102    0.136488          0.097631
# 5        0.036422   0.207281  0.039916    0.079411          0.066965
# 10       0.127814   0.458476  0.019444    0.079708          0.074847
# 15       0.102066   0.488391  0.093648    0.123366          0.224957
# 20       0.050088   0.111666  0.036604    0.153698          0.096867
# 25       0.012738   0.481010  0.032758    0.133680          0.090075
# 30       0.009679   0.288207  0.093777    0.304416          0.358946
# 35       0.389271   0.564629  0.056605    0.199719          0.174615
# 40       0.294683   0.509897  0.258474    0.473516          0.275969
# 45       0.219492   0.514960  0.060022    0.126531          0.152573
#
#         thermodynamics   geology  cartography  meteorology  genetics  \
# second
# 0             0.028760  0.017639     0.073100     0.247579  0.042502
# 5             0.016573  0.010487     0.011539     0.010492  0.015395
# 10            0.007485  0.013933     0.030218     0.014969  0.022191
# 15            0.026170  0.023282     0.235272     0.019751  0.069956
# 20            0.016462  0.008869     0.058444     0.005800  0.012876
# 25            0.004034  0.004896     0.030202     0.004939  0.011084
# 30            0.010682  0.002684     0.044723     0.004230  0.009195
# 35            0.158630  0.113846     0.100478     0.056240  0.139343
# 40            0.231262  0.131985     0.109471     0.119744  0.285112
# 45            0.073256  0.045278     0.048134     0.025291  0.079623
#
#         biochemistry   ecology
# second
# 0           0.025794  0.144981
# 5           0.004241  0.026575
# 10          0.004789  0.031851
# 15          0.047837  0.021776
# 20          0.011777  0.033530
# 25          0.002411  0.016632
# 30          0.014038  0.009353
# 35          0.169332  0.183577
# 40          0.204318  0.141391
# 45          0.029880  0.030562

# %% [markdown]
# ## Process Wendover Video

# %%
id = "8xzINLykprA"  # wendover
res = model.process(id)
res.head(10)
# Out:
# Decodes: 110
# Decodes: 120
# Decodes: 130
# Decodes: 140
# Decodes: 150
# Decodes: 160
#                                                categories  \
# second
# 0                      [marketing, economics, kinematics]
# 5                       [marketing, ecology, cartography]
# 10                        [marketing, ecology, economics]
# 15                        [economics, ecology, marketing]
# 20                 [marketing, economics, thermodynamics]
# 25                        [marketing, ecology, economics]
# 30              [marketing, economics, computer graphics]
# 35      [cartography, machine learning, computer graph...
# 40                   [ecology, marketing, thermodynamics]
# 45                   [marketing, statistics, cartography]
#
#                                                transcript  machine learning  \
# second
# 0       Let’s say I had an apple, and you had an orang...          0.158689
# 5       Let’s say I had an apple, and you had an orang...          0.470554
# 10      an apple. We could trade, and both of us would...          0.457592
# 15      the apple tree were ready, but the oranges wou...          0.533736
# 20      I could give you an apple now, and you could p...          0.268747
# 25      they’re ready, and both of us would end up hap...          0.294482
# 30      Although, maybe you didn’t want an apple. Mayb...          0.315887
# 35      But all I had to give was my apple, and I stil...          0.463465
# 40      So I give him my apple, he gives you his pear,...          0.206823
# 45      a month, and we all end up happier than when w...          0.228103
#
#         computer graphics  web development   algebra  calculus  statistics  \
# second
# 0                0.136462         0.132562  0.023201  0.089506    0.160056
# 5                0.386442         0.257986  0.131952  0.231104    0.196718
# 10               0.443588         0.249226  0.095779  0.181213    0.341756
# 15               0.372990         0.259113  0.190777  0.390482    0.559070
# 20               0.239266         0.163796  0.057906  0.246415    0.277289
# 25               0.194979         0.236495  0.059879  0.128453    0.263193
# 30               0.345521         0.320186  0.105688  0.280852    0.142487
# 35               0.461121         0.372644  0.117990  0.237746    0.170863
# 40               0.368604         0.312371  0.064057  0.308972    0.324550
# 45               0.375414         0.201140  0.171997  0.248012    0.509534
#
#         economics  marketing  commerce  kinematics  electromagnetism  \
# second
# 0        0.490699   0.492838  0.075771    0.300182          0.094515
# 5        0.440481   0.656425  0.251490    0.304621          0.230020
# 10       0.550344   0.671008  0.355401    0.423005          0.225574
# 15       0.659750   0.642501  0.311343    0.412933          0.300993
# 20       0.525106   0.583134  0.143621    0.325245          0.227507
# 25       0.321631   0.464423  0.086465    0.208427          0.131278
# 30       0.378592   0.562150  0.049880    0.344205          0.257016
# 35       0.361110   0.443685  0.046227    0.299133          0.299145
# 40       0.495737   0.530370  0.105858    0.390565          0.239597
# 45       0.368736   0.523773  0.275449    0.256837          0.208783
#
#         thermodynamics   geology  cartography  meteorology  genetics  \
# second
# 0             0.099797  0.024723     0.275216     0.046207  0.143786
# 5             0.149600  0.228571     0.540636     0.166811  0.378117
# 10            0.196103  0.264977     0.510141     0.116009  0.424253
# 15            0.362032  0.365119     0.504803     0.147429  0.543752
# 20            0.424596  0.142296     0.286449     0.074421  0.265959
# 25            0.143670  0.175345     0.301372     0.081695  0.185129
# 30            0.121460  0.219792     0.297008     0.094243  0.224451
# 35            0.138981  0.158930     0.499215     0.180143  0.277388
# 40            0.529249  0.118969     0.443272     0.086431  0.343571
# 45            0.273784  0.168003     0.437601     0.094476  0.255445
#
#         biochemistry   ecology
# second
# 0           0.214565  0.250945
# 5           0.319270  0.608170
# 10          0.266000  0.643281
# 15          0.435746  0.651600
# 20          0.337358  0.407462
# 25          0.189601  0.341408
# 30          0.218998  0.255134
# 35          0.267444  0.271976
# 40          0.262265  0.544028
# 45          0.222968  0.331305
