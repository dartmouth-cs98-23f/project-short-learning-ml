# %%
import os
from pprint import pprint 
from sklearn.preprocessing import LabelEncoder
import ast
import pandas as pd
from random_clipper import clipper
import ffmpeg
import shutil

# %%
data_dir = '../data/'
transcripts_dir = 'transcripts/'
videos_dir = 'videos/'
output_dir = 'clips/'

# %%
def trim_video(input_file, output_file, start_time, end_time):
  (
    ffmpeg.input(input_file, ss=start_time, to=end_time)
    .output(output_file)
    .run()
  )

# %%
transcript_path = data_dir+transcripts_dir
video_path = data_dir+videos_dir
output_path = data_dir+output_dir

# %%
# create clips dir
os.makedirs(data_dir+output_dir)

# %%
# create desried dir format
file_list = os.listdir(video_path)

for filename in file_list:
    # get the original .mp4 video path
    full_video_path = os.path.join(video_path, filename)

    # get the filename without extension
    base_name = os.path.splitext(filename)[0]

    # create a directory with the same name as the file
    new_directory_path = os.path.join(output_path, base_name)

    # check if the directory already exists, if not, create it
    if not os.path.exists(new_directory_path):
        os.makedirs(new_directory_path)

    # Construct the new file path in the destination directory
    new_file_path = os.path.join(new_directory_path, filename)

    # Copy the file to the new directory
    shutil.copy2(full_video_path, new_file_path)

# %%
# list all files in the transcripts directory
file_list = os.listdir(transcript_path)

# create desried dir format
for filename in file_list:
    # get the filename without extension
    base_name = os.path.splitext(filename)[0]

    clips_dir = output_path + base_name + '/'
    result = clipper(transcript_path+filename)

    for i in range(len(result)):
        start = result[i][0]
        end = result[i][1]

        # create dir just for this single clip
        curr_clip = 'video_' + str(i)
        curr_clip_dir = clips_dir + curr_clip

        # check if the directory already exists, if not, create it
        if not os.path.exists(curr_clip_dir):
            os.makedirs(curr_clip_dir)
        
        # clip it
        input_file = video_path+base_name+'.mp4'
        output_file = curr_clip_dir+'/'+curr_clip+'.mp4'
        if not os.path.exists(output_file):
            trim_video(input_file, output_file, start, end)
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13ce23550] using SAR=1/1
# [libx264 @ 0x13ce23550] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13ce23550] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x13ce23550] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_0/video_0.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  901 fps=574 q=-1.0 Lsize=     714kB time=00:00:29.97 bitrate= 195.0kbits/s dup=1 drop=0 speed=19.1x
# video:210kB audio:470kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.895103%
# [libx264 @ 0x13ce23550] frame I:4     Avg QP:14.29  size: 20596
# [libx264 @ 0x13ce23550] frame P:236   Avg QP:15.27  size:   357
# [libx264 @ 0x13ce23550] frame B:661   Avg QP:16.75  size:    73
# [libx264 @ 0x13ce23550] consecutive B-frames:  1.2%  2.0%  2.7% 94.1%
# [libx264 @ 0x13ce23550] mb I  I16..4: 40.9% 47.3% 11.8%
# [libx264 @ 0x13ce23550] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4:  0.5%  0.1%  0.1%  0.0%  0.0%    skip:99.3%
# [libx264 @ 0x13ce23550] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.4%  0.0%  0.0%  direct: 0.0%  skip:99.6%  L0:53.5% L1:43.5% BI: 3.1%
# [libx264 @ 0x13ce23550] 8x8 transform intra:46.1% inter:17.2%
# [libx264 @ 0x13ce23550] coded y,uvDC,uvAC intra: 8.4% 7.5% 6.7% inter: 0.1% 0.1% 0.0%
# [libx264 @ 0x13ce23550] i16 v,h,dc,p: 85%  9%  6%  0%
# [libx264 @ 0x13ce23550] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 80%  1% 18%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x13ce23550] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 40% 18% 19%  5%  4%  5%  3%  4%  3%
# [libx264 @ 0x13ce23550] i8c dc,h,v,p: 92%  3%  4%  0%
# [libx264 @ 0x13ce23550] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13ce23550] ref P L0: 86.6%  5.5%  5.4%  2.5%
# [libx264 @ 0x13ce23550] ref B L0: 62.1% 36.1%  1.8%
# [libx264 @ 0x13ce23550] ref B L1: 97.8%  2.2%
# [libx264 @ 0x13ce23550] kb/s:57.14
# [aac @ 0x13ce24830] Qavg: 478.544
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x1297257e0] using SAR=1/1
# [libx264 @ 0x1297257e0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x1297257e0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x1297257e0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_1/video_1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=510 q=-1.0 Lsize=    1018kB time=00:00:29.97 bitrate= 278.3kbits/s speed=  17x
# video:519kB audio:467kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.287703%
# [libx264 @ 0x1297257e0] frame I:6     Avg QP:15.25  size: 22647
# [libx264 @ 0x1297257e0] frame P:335   Avg QP:18.55  size:   968
# [libx264 @ 0x1297257e0] frame B:559   Avg QP:17.85  size:   126
# [libx264 @ 0x1297257e0] consecutive B-frames: 13.7%  8.0%  7.7% 70.7%
# [libx264 @ 0x1297257e0] mb I  I16..4: 33.2% 51.5% 15.3%
# [libx264 @ 0x1297257e0] mb P  I16..4:  1.5%  0.4%  0.2%  P16..4:  1.9%  0.4%  0.2%  0.0%  0.0%    skip:95.5%
# [libx264 @ 0x1297257e0] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  1.1%  0.1%  0.0%  direct: 0.0%  skip:98.7%  L0:48.0% L1:49.8% BI: 2.2%
# [libx264 @ 0x1297257e0] 8x8 transform intra:33.1% inter:18.9%
# [libx264 @ 0x1297257e0] coded y,uvDC,uvAC intra: 8.8% 14.0% 4.7% inter: 0.3% 0.2% 0.0%
# [libx264 @ 0x1297257e0] i16 v,h,dc,p: 91%  6%  2%  1%
# [libx264 @ 0x1297257e0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 64%  4% 31%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x1297257e0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 53% 15% 16%  3%  3%  3%  2%  4%  2%
# [libx264 @ 0x1297257e0] i8c dc,h,v,p: 61%  5% 32%  2%
# [libx264 @ 0x1297257e0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x1297257e0] ref P L0: 87.0%  6.8%  4.5%  1.7%
# [libx264 @ 0x1297257e0] ref B L0: 70.7% 27.6%  1.7%
# [libx264 @ 0x1297257e0] ref B L1: 97.3%  2.7%
# [libx264 @ 0x1297257e0] kb/s:141.31
# [aac @ 0x129726a50] Qavg: 496.073
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13461a610] using SAR=1/1
# [libx264 @ 0x13461a610] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13461a610] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x13461a610] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_2/video_2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=563 q=-1.0 Lsize=     835kB time=00:00:29.97 bitrate= 228.3kbits/s speed=18.8x
# video:342kB audio:460kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.113774%
# [libx264 @ 0x13461a610] frame I:4     Avg QP:16.22  size: 23562
# [libx264 @ 0x13461a610] frame P:280   Avg QP:16.73  size:   653
# [libx264 @ 0x13461a610] frame B:616   Avg QP:15.98  size:   118
# [libx264 @ 0x13461a610] consecutive B-frames:  6.2%  6.0%  4.7% 83.1%
# [libx264 @ 0x13461a610] mb I  I16..4: 17.8% 67.9% 14.2%
# [libx264 @ 0x13461a610] mb P  I16..4:  0.5%  0.2%  0.1%  P16..4:  1.2%  0.2%  0.1%  0.0%  0.0%    skip:97.6%
# [libx264 @ 0x13461a610] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.8%  0.1%  0.0%  direct: 0.1%  skip:98.9%  L0:52.1% L1:46.0% BI: 1.9%
# [libx264 @ 0x13461a610] 8x8 transform intra:50.9% inter:16.2%
# [libx264 @ 0x13461a610] coded y,uvDC,uvAC intra: 8.7% 8.9% 5.0% inter: 0.1% 0.2% 0.0%
# [libx264 @ 0x13461a610] i16 v,h,dc,p: 75% 21%  5%  0%
# [libx264 @ 0x13461a610] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 68%  6% 25%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x13461a610] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 44% 18% 16%  4%  3%  5%  2%  6%  2%
# [libx264 @ 0x13461a610] i8c dc,h,v,p: 70%  2% 26%  2%
# [libx264 @ 0x13461a610] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13461a610] ref P L0: 82.8%  5.0%  8.3%  3.9%
# [libx264 @ 0x13461a610] ref B L0: 61.9% 35.8%  2.3%
# [libx264 @ 0x13461a610] ref B L1: 98.0%  2.0%
# [libx264 @ 0x13461a610] kb/s:93.15
# [aac @ 0x13461b8f0] Qavg: 2136.286
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x11ce05200] using SAR=1/1
# [libx264 @ 0x11ce05200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x11ce05200] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x11ce05200] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_3/video_3.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=523 q=-1.0 Lsize=     987kB time=00:00:29.97 bitrate= 269.8kbits/s speed=17.4x
# video:488kB audio:467kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.371159%
# [libx264 @ 0x11ce05200] frame I:4     Avg QP:16.64  size: 18802
# [libx264 @ 0x11ce05200] frame P:359   Avg QP:17.34  size:  1038
# [libx264 @ 0x11ce05200] frame B:537   Avg QP:15.48  size:    95
# [libx264 @ 0x11ce05200] consecutive B-frames: 17.9%  7.1%  1.7% 73.3%
# [libx264 @ 0x11ce05200] mb I  I16..4: 35.9% 52.5% 11.6%
# [libx264 @ 0x11ce05200] mb P  I16..4:  2.2%  0.7%  0.2%  P16..4:  2.3%  0.3%  0.2%  0.0%  0.0%    skip:94.1%
# [libx264 @ 0x11ce05200] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.0%  0.0%  0.0%  direct: 0.1%  skip:98.8%  L0:47.9% L1:51.0% BI: 1.1%
# [libx264 @ 0x11ce05200] 8x8 transform intra:31.1% inter:23.7%
# [libx264 @ 0x11ce05200] coded y,uvDC,uvAC intra: 6.6% 12.9% 2.7% inter: 0.4% 0.4% 0.0%
# [libx264 @ 0x11ce05200] i16 v,h,dc,p: 91%  7%  2%  0%
# [libx264 @ 0x11ce05200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46%  5% 48%  0%  0%  0%  0%  1%  0%
# [libx264 @ 0x11ce05200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 55% 12% 18%  3%  2%  3%  1%  4%  1%
# [libx264 @ 0x11ce05200] i8c dc,h,v,p: 50%  4% 44%  2%
# [libx264 @ 0x11ce05200] Weighted P-Frames: Y:1.4% UV:0.3%
# [libx264 @ 0x11ce05200] ref P L0: 84.0% 10.6%  3.9%  1.5%  0.1%
# [libx264 @ 0x11ce05200] ref B L0: 72.7% 26.3%  1.0%
# [libx264 @ 0x11ce05200] ref B L1: 97.9%  2.1%
# [libx264 @ 0x11ce05200] kb/s:132.85
# [aac @ 0x11ce064e0] Qavg: 579.039
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x132f2a270] using SAR=1/1
# [libx264 @ 0x132f2a270] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x132f2a270] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x132f2a270] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_4/video_4.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=592 q=-1.0 Lsize=     716kB time=00:00:29.97 bitrate= 195.7kbits/s speed=19.7x
# video:239kB audio:444kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.880787%
# [libx264 @ 0x132f2a270] frame I:5     Avg QP:16.02  size: 22842
# [libx264 @ 0x132f2a270] frame P:232   Avg QP:14.50  size:   343
# [libx264 @ 0x132f2a270] frame B:663   Avg QP:15.12  size:    75
# [libx264 @ 0x132f2a270] consecutive B-frames:  0.9%  2.2%  1.3% 95.6%
# [libx264 @ 0x132f2a270] mb I  I16..4: 25.9% 61.3% 12.8%
# [libx264 @ 0x132f2a270] mb P  I16..4:  0.1%  0.1%  0.1%  P16..4:  0.7%  0.1%  0.1%  0.0%  0.0%    skip:98.9%
# [libx264 @ 0x132f2a270] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.6%  0.0%  0.0%  direct: 0.0%  skip:99.4%  L0:54.7% L1:44.0% BI: 1.3%
# [libx264 @ 0x132f2a270] 8x8 transform intra:56.8% inter:24.9%
# [libx264 @ 0x132f2a270] coded y,uvDC,uvAC intra: 9.0% 9.4% 7.1% inter: 0.1% 0.1% 0.0%
# [libx264 @ 0x132f2a270] i16 v,h,dc,p: 82% 11%  8%  0%
# [libx264 @ 0x132f2a270] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 63%  6% 31%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x132f2a270] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 41% 17% 18%  5%  3%  4%  2%  8%  2%
# [libx264 @ 0x132f2a270] i8c dc,h,v,p: 80%  4% 16%  1%
# [libx264 @ 0x132f2a270] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x132f2a270] ref P L0: 84.8%  4.0%  8.4%  2.9%
# [libx264 @ 0x132f2a270] ref B L0: 54.9% 43.3%  1.8%
# [libx264 @ 0x132f2a270] ref B L1: 96.7%  3.3%
# [libx264 @ 0x132f2a270] kb/s:64.89
# [aac @ 0x132f2b550] Qavg: 3894.587
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x140f05ed0] using SAR=1/1
# [libx264 @ 0x140f05ed0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x140f05ed0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x140f05ed0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_5/video_5.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  901 fps=565 q=-1.0 Lsize=     908kB time=00:00:29.97 bitrate= 248.2kbits/s dup=1 drop=0 speed=18.8x
# video:408kB audio:467kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.767996%
# [libx264 @ 0x140f05ed0] frame I:4     Avg QP:14.79  size: 20775
# [libx264 @ 0x140f05ed0] frame P:284   Avg QP:16.57  size:   907
# [libx264 @ 0x140f05ed0] frame B:613   Avg QP:16.98  size:   125
# [libx264 @ 0x140f05ed0] consecutive B-frames:  5.9%  8.0%  6.7% 79.5%
# [libx264 @ 0x140f05ed0] mb I  I16..4: 34.6% 52.8% 12.6%
# [libx264 @ 0x140f05ed0] mb P  I16..4:  1.6%  0.6%  0.1%  P16..4:  2.2%  0.3%  0.2%  0.0%  0.0%    skip:95.0%
# [libx264 @ 0x140f05ed0] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  0.9%  0.1%  0.0%  direct: 0.2%  skip:98.7%  L0:47.3% L1:50.1% BI: 2.6%
# [libx264 @ 0x140f05ed0] 8x8 transform intra:35.8% inter:27.0%
# [libx264 @ 0x140f05ed0] coded y,uvDC,uvAC intra: 6.0% 16.4% 5.9% inter: 0.3% 0.6% 0.1%
# [libx264 @ 0x140f05ed0] i16 v,h,dc,p: 88%  8%  3%  0%
# [libx264 @ 0x140f05ed0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46%  6% 46%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x140f05ed0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 16% 24%  4%  3%  4%  2%  6%  2%
# [libx264 @ 0x140f05ed0] i8c dc,h,v,p: 46%  5% 46%  3%
# [libx264 @ 0x140f05ed0] Weighted P-Frames: Y:3.5% UV:3.2%
# [libx264 @ 0x140f05ed0] ref P L0: 78.7%  9.5%  9.3%  2.4%  0.2%
# [libx264 @ 0x140f05ed0] ref B L0: 74.5% 23.7%  1.8%
# [libx264 @ 0x140f05ed0] ref B L1: 96.7%  3.3%
# [libx264 @ 0x140f05ed0] kb/s:111.01
# [aac @ 0x140f07170] Qavg: 605.244
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x122e118f0] using SAR=1/1
# [libx264 @ 0x122e118f0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x122e118f0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x122e118f0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_6/video_6.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  901 fps=523 q=-1.0 Lsize=    1136kB time=00:00:29.97 bitrate= 310.5kbits/s dup=1 drop=0 speed=17.4x
# video:661kB audio:443kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.911382%
# [libx264 @ 0x122e118f0] frame I:5     Avg QP:14.23  size: 17611
# [libx264 @ 0x122e118f0] frame P:358   Avg QP:20.91  size:  1324
# [libx264 @ 0x122e118f0] frame B:538   Avg QP:18.96  size:   212
# [libx264 @ 0x122e118f0] consecutive B-frames: 15.6% 10.4% 11.3% 62.6%
# [libx264 @ 0x122e118f0] mb I  I16..4: 39.0% 49.2% 11.9%
# [libx264 @ 0x122e118f0] mb P  I16..4:  2.5%  1.8%  0.3%  P16..4:  2.6%  0.5%  0.3%  0.0%  0.0%    skip:91.9%
# [libx264 @ 0x122e118f0] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8:  1.9%  0.1%  0.0%  direct: 0.3%  skip:97.4%  L0:53.1% L1:44.3% BI: 2.6%
# [libx264 @ 0x122e118f0] 8x8 transform intra:41.9% inter:29.6%
# [libx264 @ 0x122e118f0] coded y,uvDC,uvAC intra: 7.2% 10.8% 3.0% inter: 0.6% 0.5% 0.1%
# [libx264 @ 0x122e118f0] i16 v,h,dc,p: 91%  7%  2%  0%
# [libx264 @ 0x122e118f0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 64%  6% 28%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x122e118f0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 53% 16% 16%  3%  3%  3%  2%  3%  2%
# [libx264 @ 0x122e118f0] i8c dc,h,v,p: 68%  5% 27%  1%
# [libx264 @ 0x122e118f0] Weighted P-Frames: Y:6.4% UV:5.3%
# [libx264 @ 0x122e118f0] ref P L0: 72.6% 11.3% 11.8%  4.1%  0.2%
# [libx264 @ 0x122e118f0] ref B L0: 63.4% 34.8%  1.8%
# [libx264 @ 0x122e118f0] ref B L1: 97.1%  2.9%
# [libx264 @ 0x122e118f0] kb/s:179.97
# [aac @ 0x122e12bd0] Qavg: 4320.134
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x122e377a0] using SAR=1/1
# [libx264 @ 0x122e377a0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x122e377a0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x122e377a0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_7/video_7.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=528 q=-1.0 Lsize=     840kB time=00:00:29.97 bitrate= 229.7kbits/s speed=17.6x
# video:339kB audio:468kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.037824%
# [libx264 @ 0x122e377a0] frame I:5     Avg QP:13.87  size: 16011
# [libx264 @ 0x122e377a0] frame P:313   Avg QP:15.98  size:   619
# [libx264 @ 0x122e377a0] frame B:582   Avg QP:16.98  size:   126
# [libx264 @ 0x122e377a0] consecutive B-frames: 10.8%  6.9%  6.3% 76.0%
# [libx264 @ 0x122e377a0] mb I  I16..4: 42.9% 47.3%  9.8%
# [libx264 @ 0x122e377a0] mb P  I16..4:  1.3%  0.4%  0.1%  P16..4:  0.8%  0.2%  0.1%  0.0%  0.0%    skip:97.1%
# [libx264 @ 0x122e377a0] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  0.9%  0.1%  0.0%  direct: 0.0%  skip:98.8%  L0:49.1% L1:47.4% BI: 3.5%
# [libx264 @ 0x122e377a0] 8x8 transform intra:33.8% inter:32.8%
# [libx264 @ 0x122e377a0] coded y,uvDC,uvAC intra: 6.9% 13.6% 4.4% inter: 0.2% 0.2% 0.0%
# [libx264 @ 0x122e377a0] i16 v,h,dc,p: 91%  5%  3%  0%
# [libx264 @ 0x122e377a0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 68%  3% 28%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x122e377a0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 15% 23%  4%  1%  2%  2%  4%  2%
# [libx264 @ 0x122e377a0] i8c dc,h,v,p: 56%  5% 38%  1%
# [libx264 @ 0x122e377a0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x122e377a0] ref P L0: 77.1% 10.5%  8.6%  3.8%
# [libx264 @ 0x122e377a0] ref B L0: 67.5% 30.2%  2.2%
# [libx264 @ 0x122e377a0] ref B L1: 96.8%  3.2%
# [libx264 @ 0x122e377a0] kb/s:92.42
# [aac @ 0x122e38a80] Qavg: 519.886
# ...
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  720 fps=222 q=-1.0 Lsize=    3022kB time=00:00:29.97 bitrate= 825.9kbits/s speed=9.23x
# video:2531kB audio:469kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.757281%
# [libx264 @ 0x144e378b0] frame I:4     Avg QP:16.80  size: 21051
# [libx264 @ 0x144e378b0] frame P:269   Avg QP:19.33  size:  6444
# [libx264 @ 0x144e378b0] frame B:447   Avg QP:20.57  size:  1729
# [libx264 @ 0x144e378b0] consecutive B-frames:  1.4% 23.6% 71.7%  3.3%
# [libx264 @ 0x144e378b0] mb I  I16..4: 36.3% 56.7%  7.0%
# [libx264 @ 0x144e378b0] mb P  I16..4:  7.1% 11.8%  0.4%  P16..4: 29.8%  4.7%  1.1%  0.0%  0.0%    skip:45.2%
# [libx264 @ 0x144e378b0] mb B  I16..4:  0.4%  0.4%  0.0%  B16..8: 25.0%  1.2%  0.0%  direct: 1.0%  skip:72.1%  L0:35.6% L1:62.5% BI: 1.9%
# [libx264 @ 0x144e378b0] 8x8 transform intra:60.3% inter:88.8%
# [libx264 @ 0x144e378b0] coded y,uvDC,uvAC intra: 15.9% 31.5% 6.8% inter: 2.4% 4.5% 0.1%
# [libx264 @ 0x144e378b0] i16 v,h,dc,p: 23% 27% 11% 39%
# [libx264 @ 0x144e378b0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 21% 45%  2%  2%  2%  3%  2%  2%
# [libx264 @ 0x144e378b0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 31% 22%  3%  7%  4% 10%  2%  2%
# [libx264 @ 0x144e378b0] i8c dc,h,v,p: 68% 17% 12%  3%
# [libx264 @ 0x144e378b0] Weighted P-Frames: Y:0.4% UV:0.4%
# [libx264 @ 0x144e378b0] ref P L0: 72.4% 12.1% 10.4%  5.1%  0.0%
# [libx264 @ 0x144e378b0] ref B L0: 79.9% 17.8%  2.2%
# [libx264 @ 0x144e378b0] ref B L1: 99.8%  0.2%
# [libx264 @ 0x144e378b0] kb/s:690.13
# [aac @ 0x144e38b90] Qavg: 515.766
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Arts&Crafts_Crocheting_How_to_Crochet_for_Absolute_Beginners:_Part_1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-10-08T16:01:48.000000Z
#   Duration: 00:08:35.85, start: 0.000000, bitrate: 592 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 461 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x156f26190] using SAR=1/1
# [libx264 @ 0x156f26190] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x156f26190] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x156f26190] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Arts&Crafts_Crocheting_How_to_Crochet_for_Absolute_Beginners:_Part_1/video_10/video_10.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 23.98 fps, 24k tbn (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  721 fps=200 q=-1.0 Lsize=    3670kB time=00:00:29.97 bitrate=1003.0kbits/s dup=1 drop=0 speed= 8.3x
# video:3176kB audio:471kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.634274%
# [libx264 @ 0x156f26190] frame I:4     Avg QP:17.30  size: 25054
# [libx264 @ 0x156f26190] frame P:275   Avg QP:19.86  size:  7940
# [libx264 @ 0x156f26190] frame B:442   Avg QP:22.18  size:  2190
# [libx264 @ 0x156f26190] consecutive B-frames:  0.8% 35.2% 51.2% 12.8%
# [libx264 @ 0x156f26190] mb I  I16..4: 40.4% 50.3%  9.2%
# [libx264 @ 0x156f26190] mb P  I16..4:  9.6% 13.9%  0.7%  P16..4: 27.9%  4.9%  1.2%  0.0%  0.0%    skip:41.8%
# [libx264 @ 0x156f26190] mb B  I16..4:  0.6%  0.9%  0.0%  B16..8: 25.3%  1.6%  0.1%  direct: 0.9%  skip:70.5%  L0:38.8% L1:58.7% BI: 2.5%
# [libx264 @ 0x156f26190] 8x8 transform intra:56.8% inter:85.9%
# [libx264 @ 0x156f26190] coded y,uvDC,uvAC intra: 22.9% 36.1% 8.2% inter: 3.2% 5.7% 0.1%
# [libx264 @ 0x156f26190] i16 v,h,dc,p: 26% 24% 11% 39%
# [libx264 @ 0x156f26190] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 21% 33%  2%  4%  4%  3%  3%  3%
# [libx264 @ 0x156f26190] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 19% 20%  3%  8%  7%  6%  3%  2%
# [libx264 @ 0x156f26190] i8c dc,h,v,p: 64% 17% 15%  4%
# [libx264 @ 0x156f26190] Weighted P-Frames: Y:6.5% UV:1.5%
# [libx264 @ 0x156f26190] ref P L0: 69.1% 14.0% 11.4%  5.3%  0.2%
# [libx264 @ 0x156f26190] ref B L0: 83.3% 15.2%  1.6%
# [libx264 @ 0x156f26190] ref B L1: 99.2%  0.8%
# [libx264 @ 0x156f26190] kb/s:865.02
# [aac @ 0x156f27470] Qavg: 596.067
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Arts&Crafts_Crocheting_How_to_Crochet_for_Absolute_Beginners:_Part_1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-10-08T16:01:48.000000Z
#   Duration: 00:08:35.85, start: 0.000000, bitrate: 592 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 461 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14df084f0] using SAR=1/1
# [libx264 @ 0x14df084f0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14df084f0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x14df084f0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Arts&Crafts_Crocheting_How_to_Crochet_for_Absolute_Beginners:_Part_1/video_11/video_11.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 23.98 fps, 24k tbn (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-08T16:01:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 10/08/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  721 fps=220 q=-1.0 Lsize=    3024kB time=00:00:29.97 bitrate= 826.3kbits/s dup=1 drop=0 speed=9.15x
# video:2532kB audio:469kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.759571%
# [libx264 @ 0x14df084f0] frame I:3     Avg QP:17.47  size: 22228
# [libx264 @ 0x14df084f0] frame P:268   Avg QP:19.69  size:  6482
# [libx264 @ 0x14df084f0] frame B:450   Avg QP:20.83  size:  1752
# [libx264 @ 0x14df084f0] consecutive B-frames:  1.1% 23.9% 69.5%  5.5%
# [libx264 @ 0x14df084f0] mb I  I16..4: 34.4% 60.4%  5.3%
# [libx264 @ 0x14df084f0] mb P  I16..4:  7.3% 12.3%  0.3%  P16..4: 29.9%  4.6%  1.1%  0.0%  0.0%    skip:44.6%
# [libx264 @ 0x14df084f0] mb B  I16..4:  0.4%  0.4%  0.0%  B16..8: 25.6%  1.1%  0.0%  direct: 0.9%  skip:71.6%  L0:35.1% L1:62.8% BI: 2.1%
# [libx264 @ 0x14df084f0] 8x8 transform intra:61.0% inter:90.1%
# [libx264 @ 0x14df084f0] coded y,uvDC,uvAC intra: 16.2% 31.1% 6.1% inter: 2.5% 4.5% 0.1%
# [libx264 @ 0x14df084f0] i16 v,h,dc,p: 21% 28% 11% 40%
# [libx264 @ 0x14df084f0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 22% 44%  2%  2%  2%  3%  2%  2%
# [libx264 @ 0x14df084f0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 28% 24%  2%  9%  6%  8%  2%  2%
# [libx264 @ 0x14df084f0] i8c dc,h,v,p: 70% 16% 11%  3%
# [libx264 @ 0x14df084f0] Weighted P-Frames: Y:5.6% UV:1.1%
# [libx264 @ 0x14df084f0] ref P L0: 70.8% 12.7% 11.2%  5.1%  0.2%
# [libx264 @ 0x14df084f0] ref B L0: 81.5% 16.3%  2.2%
# [libx264 @ 0x14df084f0] ref B L1: 99.5%  0.5%
# [libx264 @ 0x14df084f0] kb/s:689.63
# [aac @ 0x14df097f0] Qavg: 535.110
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 10
#       7 base_name = os.path.splitext(filename)[0]
#       9 clips_dir = output_path + base_name + '/'
# ---> 10 result = clipper(transcript_path+filename)
#      12 for i in range(len(result)):
#      13     start = result[i][0]
#
# File ~/Desktop/COSC98/project/project-short-learning-ml/app/utils/clipper/random_clipper.py:12, in clipper(filename)
#      10 duration = df['second'].iloc[-1]
#      11 clips = int(duration//60)
# ---> 12 return sorted(extract_random_clip_times(duration, num_clips=clips), key=lambda x: x[0].total_seconds())
#
# File ~/Desktop/COSC98/project/project-short-learning-ml/app/utils/clipper/random_clipper.py:27, in extract_random_clip_times(total_video_length, clip_duration, num_clips)
#      20 end_time = start_time + clip_duration
#      22 # print(start_time, end_time)
#      23 # print(used_times)
#      24 # print('----------------------------------------------------------------')
#      25
#      26 # Ensure non-overlapping by checking against used times
# ---> 27 while any(existing_start <= start_time <= existing_end or existing_start <= end_time <= existing_end
#      28           for existing_start, existing_end in used_times):
#      29     start_time = random.uniform(0, total_video_length - clip_duration)
#      30     end_time = start_time + clip_duration
#
# File ~/Desktop/COSC98/project/project-short-learning-ml/app/utils/clipper/random_clipper.py:27, in <genexpr>(.0)
#      20 end_time = start_time + clip_duration
#      22 # print(start_time, end_time)
#      23 # print(used_times)
#      24 # print('----------------------------------------------------------------')
#      25
#      26 # Ensure non-overlapping by checking against used times
# ---> 27 while any(existing_start <= start_time <= existing_end or existing_start <= end_time <= existing_end
#      28           for existing_start, existing_end in used_times):
#      29     start_time = random.uniform(0, total_video_length - clip_duration)
#      30     end_time = start_time + clip_duration
#
# KeyboardInterrupt:
