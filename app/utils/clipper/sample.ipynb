# %%
import os
from pprint import pprint 
from sklearn.preprocessing import LabelEncoder
import ast
import pandas as pd
from random_clipper import clipper
import ffmpeg
import shutil

# %%
data_dir = '../data/'
transcripts_dir = 'transcripts/'
videos_dir = 'videos/'
output_dir = 'clips/'

# %%
def trim_video(input_file, output_file, start_time, end_time):
  (
    ffmpeg.input(input_file, ss=start_time, to=end_time)
    .output(output_file)
    .run()
  )

# %%
transcript_path = data_dir+transcripts_dir
video_path = data_dir+videos_dir
output_path = data_dir+output_dir

# %%
# create clips dir
os.makedirs(data_dir+output_dir)

# %%
# create desried dir format
file_list = os.listdir(video_path)

for filename in file_list:
    # get the original .mp4 video path
    full_video_path = os.path.join(video_path, filename)

    # get the filename without extension
    base_name = os.path.splitext(filename)[0]

    # create a directory with the same name as the file
    new_directory_path = os.path.join(output_path, base_name)

    # check if the directory already exists, if not, create it
    if not os.path.exists(new_directory_path):
        os.makedirs(new_directory_path)

    # Construct the new file path in the destination directory
    new_file_path = os.path.join(new_directory_path, filename)

    # Copy the file to the new directory
    shutil.copy2(full_video_path, new_file_path)

# %%
# list all files in the transcripts directory
file_list = os.listdir(transcript_path)

# create desried dir format
for filename in file_list:
    # get the filename without extension
    base_name = os.path.splitext(filename)[0]

    clips_dir = output_path + base_name + '/'
    result = clipper(transcript_path+filename)

    for i in range(len(result)):
        start = result[i][0]
        end = result[i][1]

        # create dir just for this single clip
        curr_clip = 'video_' + str(i)
        curr_clip_dir = clips_dir + curr_clip

        # check if the directory already exists, if not, create it
        if not os.path.exists(curr_clip_dir):
            os.makedirs(curr_clip_dir)
        
        # clip it
        input_file = video_path+base_name+'.mp4'
        output_file = curr_clip_dir+'/'+curr_clip+'.mp4'
        if not os.path.exists(output_file):
            trim_video(input_file, output_file, start, end)
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13c7249d0] using SAR=1/1
# [libx264 @ 0x13c7249d0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13c7249d0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x13c7249d0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_0/video_0.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  901 fps=542 q=-1.0 Lsize=     806kB time=00:00:29.97 bitrate= 220.3kbits/s dup=1 drop=0 speed=  18x
# video:346kB audio:427kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.258600%
# [libx264 @ 0x13c7249d0] frame I:4     Avg QP:11.77  size: 13512
# [libx264 @ 0x13c7249d0] frame P:296   Avg QP:18.82  size:   678
# [libx264 @ 0x13c7249d0] frame B:601   Avg QP:20.00  size:   165
# [libx264 @ 0x13c7249d0] consecutive B-frames:  5.8% 12.4% 10.3% 71.5%
# [libx264 @ 0x13c7249d0] mb I  I16..4: 48.3% 42.4%  9.4%
# [libx264 @ 0x13c7249d0] mb P  I16..4:  0.2%  0.1%  0.1%  P16..4:  1.4%  0.3%  0.2%  0.0%  0.0%    skip:97.7%
# [libx264 @ 0x13c7249d0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.9%  0.1%  0.0%  direct: 0.0%  skip:98.9%  L0:50.2% L1:45.8% BI: 4.0%
# [libx264 @ 0x13c7249d0] 8x8 transform intra:40.3% inter:15.5%
# [libx264 @ 0x13c7249d0] coded y,uvDC,uvAC intra: 8.5% 6.7% 5.4% inter: 0.2% 0.1% 0.0%
# [libx264 @ 0x13c7249d0] i16 v,h,dc,p: 79% 17%  4%  0%
# [libx264 @ 0x13c7249d0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 58%  4% 37%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x13c7249d0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 20% 25%  3%  3%  4%  3%  5%  3%
# [libx264 @ 0x13c7249d0] i8c dc,h,v,p: 89%  7%  3%  0%
# [libx264 @ 0x13c7249d0] Weighted P-Frames: Y:0.3% UV:0.0%
# [libx264 @ 0x13c7249d0] ref P L0: 80.9%  4.5%  9.8%  4.8%  0.0%
# [libx264 @ 0x13c7249d0] ref B L0: 71.8% 26.0%  2.1%
# [libx264 @ 0x13c7249d0] ref B L1: 97.0%  3.0%
# [libx264 @ 0x13c7249d0] kb/s:94.21
# [aac @ 0x13c618980] Qavg: 6897.038
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13ef21750] using SAR=1/1
# [libx264 @ 0x13ef21750] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13ef21750] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x13ef21750] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_1/video_1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=563 q=-1.0 Lsize=     932kB time=00:00:29.97 bitrate= 254.8kbits/s speed=18.7x
# video:440kB audio:459kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.639243%
# [libx264 @ 0x13ef21750] frame I:4     Avg QP:11.93  size: 18125
# [libx264 @ 0x13ef21750] frame P:302   Avg QP:18.23  size:  1011
# [libx264 @ 0x13ef21750] frame B:594   Avg QP:17.72  size:   122
# [libx264 @ 0x13ef21750] consecutive B-frames:  9.3%  6.7%  4.0% 80.0%
# [libx264 @ 0x13ef21750] mb I  I16..4: 59.1% 30.0% 10.9%
# [libx264 @ 0x13ef21750] mb P  I16..4:  1.7%  0.7%  0.2%  P16..4:  1.7%  0.4%  0.2%  0.0%  0.0%    skip:95.0%
# [libx264 @ 0x13ef21750] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.2%  0.1%  0.0%  direct: 0.0%  skip:98.6%  L0:46.8% L1:50.6% BI: 2.6%
# [libx264 @ 0x13ef21750] 8x8 transform intra:28.4% inter:26.0%
# [libx264 @ 0x13ef21750] coded y,uvDC,uvAC intra: 7.3% 10.7% 4.4% inter: 0.3% 0.2% 0.0%
# [libx264 @ 0x13ef21750] i16 v,h,dc,p: 90%  8%  2%  0%
# [libx264 @ 0x13ef21750] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 48%  7% 43%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x13ef21750] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 19% 27%  3%  3%  4%  2%  3%  2%
# [libx264 @ 0x13ef21750] i8c dc,h,v,p: 58%  6% 35%  1%
# [libx264 @ 0x13ef21750] Weighted P-Frames: Y:4.6% UV:4.3%
# [libx264 @ 0x13ef21750] ref P L0: 78.5%  7.3% 11.7%  2.3%  0.2%
# [libx264 @ 0x13ef21750] ref B L0: 73.1% 25.2%  1.7%
# [libx264 @ 0x13ef21750] ref B L1: 97.4%  2.6%
# [libx264 @ 0x13ef21750] kb/s:119.94
# [aac @ 0x13ef229b0] Qavg: 1968.155
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x151706ce0] using SAR=1/1
# [libx264 @ 0x151706ce0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x151706ce0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x151706ce0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_2/video_2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  901 fps=612 q=-1.0 Lsize=     870kB time=00:00:29.97 bitrate= 237.7kbits/s dup=1 drop=0 speed=20.4x
# video:394kB audio:443kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.928242%
# [libx264 @ 0x151706ce0] frame I:4     Avg QP:13.56  size: 15572
# [libx264 @ 0x151706ce0] frame P:289   Avg QP:16.93  size:   775
# [libx264 @ 0x151706ce0] frame B:608   Avg QP:17.17  size:   192
# [libx264 @ 0x151706ce0] consecutive B-frames:  7.1%  6.2%  7.7% 79.0%
# [libx264 @ 0x151706ce0] mb I  I16..4: 46.4% 43.9%  9.7%
# [libx264 @ 0x151706ce0] mb P  I16..4:  0.7%  0.4%  0.2%  P16..4:  1.1%  0.3%  0.1%  0.0%  0.0%    skip:97.3%
# [libx264 @ 0x151706ce0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.9%  0.1%  0.0%  direct: 0.0%  skip:98.9%  L0:52.8% L1:43.6% BI: 3.6%
# [libx264 @ 0x151706ce0] 8x8 transform intra:36.1% inter:26.8%
# [libx264 @ 0x151706ce0] coded y,uvDC,uvAC intra: 11.5% 12.8% 6.5% inter: 0.2% 0.2% 0.0%
# [libx264 @ 0x151706ce0] i16 v,h,dc,p: 53% 43%  4%  0%
# [libx264 @ 0x151706ce0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 52% 14% 33%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x151706ce0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 23% 21%  3%  3%  5%  3%  4%  2%
# [libx264 @ 0x151706ce0] i8c dc,h,v,p: 76% 18%  6%  0%
# [libx264 @ 0x151706ce0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x151706ce0] ref P L0: 68.5% 14.0% 12.3%  5.2%
# [libx264 @ 0x151706ce0] ref B L0: 70.9% 26.2%  2.9%
# [libx264 @ 0x151706ce0] ref B L1: 97.8%  2.2%
# [libx264 @ 0x151706ce0] kb/s:107.24
# [aac @ 0x151707f80] Qavg: 4505.495
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12df261a0] using SAR=1/1
# [libx264 @ 0x12df261a0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12df261a0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x12df261a0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_3/video_3.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=531 q=-1.0 Lsize=     827kB time=00:00:29.97 bitrate= 226.1kbits/s speed=17.7x
# video:369kB audio:426kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.045171%
# [libx264 @ 0x12df261a0] frame I:4     Avg QP:13.95  size: 13341
# [libx264 @ 0x12df261a0] frame P:357   Avg QP:17.86  size:   774
# [libx264 @ 0x12df261a0] frame B:539   Avg QP:14.98  size:    89
# [libx264 @ 0x12df261a0] consecutive B-frames: 18.9%  3.3%  1.3% 76.4%
# [libx264 @ 0x12df261a0] mb I  I16..4: 48.2% 42.8%  9.0%
# [libx264 @ 0x12df261a0] mb P  I16..4:  3.0%  0.5%  0.3%  P16..4:  1.2%  0.3%  0.1%  0.0%  0.0%    skip:94.7%
# [libx264 @ 0x12df261a0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.0%  0.0%  0.0%  direct: 0.0%  skip:98.9%  L0:48.6% L1:50.5% BI: 0.9%
# [libx264 @ 0x12df261a0] 8x8 transform intra:20.0% inter:33.6%
# [libx264 @ 0x12df261a0] coded y,uvDC,uvAC intra: 6.4% 13.7% 3.2% inter: 0.2% 0.2% 0.0%
# [libx264 @ 0x12df261a0] i16 v,h,dc,p: 95%  4%  1%  0%
# [libx264 @ 0x12df261a0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 61%  6% 33%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x12df261a0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 59% 15% 18%  2%  1%  2%  1%  2%  1%
# [libx264 @ 0x12df261a0] i8c dc,h,v,p: 48%  5% 46%  1%
# [libx264 @ 0x12df261a0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12df261a0] ref P L0: 85.2%  8.3%  5.2%  1.4%
# [libx264 @ 0x12df261a0] ref B L0: 69.8% 29.1%  1.2%
# [libx264 @ 0x12df261a0] ref B L1: 97.3%  2.7%
# [libx264 @ 0x12df261a0] kb/s:100.55
# [aac @ 0x12de17120] Qavg: 7312.841
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13ee1a920] using SAR=1/1
# [libx264 @ 0x13ee1a920] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13ee1a920] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x13ee1a920] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_4/video_4.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=563 q=-1.0 Lsize=     758kB time=00:00:29.97 bitrate= 207.2kbits/s speed=18.8x
# video:257kB audio:468kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.566662%
# [libx264 @ 0x13ee1a920] frame I:5     Avg QP:14.81  size: 19627
# [libx264 @ 0x13ee1a920] frame P:248   Avg QP:15.26  size:   455
# [libx264 @ 0x13ee1a920] frame B:647   Avg QP:15.00  size:    80
# [libx264 @ 0x13ee1a920] consecutive B-frames:  3.9%  0.4%  1.0% 94.7%
# [libx264 @ 0x13ee1a920] mb I  I16..4: 38.9% 47.7% 13.4%
# [libx264 @ 0x13ee1a920] mb P  I16..4:  0.6%  0.3%  0.1%  P16..4:  0.9%  0.2%  0.1%  0.0%  0.0%    skip:97.8%
# [libx264 @ 0x13ee1a920] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.9%  0.0%  0.0%  direct: 0.0%  skip:99.1%  L0:62.2% L1:37.5% BI: 0.3%
# [libx264 @ 0x13ee1a920] 8x8 transform intra:42.1% inter:33.7%
# [libx264 @ 0x13ee1a920] coded y,uvDC,uvAC intra: 9.1% 9.5% 4.9% inter: 0.1% 0.1% 0.0%
# [libx264 @ 0x13ee1a920] i16 v,h,dc,p: 90%  6%  4%  0%
# [libx264 @ 0x13ee1a920] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 70%  3% 27%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x13ee1a920] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 48% 17% 17%  3%  2%  3%  2%  4%  2%
# [libx264 @ 0x13ee1a920] i8c dc,h,v,p: 78%  4% 17%  1%
# [libx264 @ 0x13ee1a920] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13ee1a920] ref P L0: 79.3% 14.3%  4.5%  1.8%
# [libx264 @ 0x13ee1a920] ref B L0: 37.6% 62.0%  0.4%
# [libx264 @ 0x13ee1a920] ref B L1: 98.0%  2.0%
# [libx264 @ 0x13ee1a920] kb/s:69.96
# [aac @ 0x13ee1bc00] Qavg: 591.867
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12b005d60] using SAR=1/1
# [libx264 @ 0x12b005d60] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12b005d60] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x12b005d60] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_5/video_5.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=551 q=-1.0 Lsize=     964kB time=00:00:29.97 bitrate= 263.3kbits/s speed=18.3x
# video:493kB audio:438kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.462177%
# [libx264 @ 0x12b005d60] frame I:5     Avg QP:13.93  size: 15528
# [libx264 @ 0x12b005d60] frame P:357   Avg QP:20.65  size:   939
# [libx264 @ 0x12b005d60] frame B:538   Avg QP:16.92  size:   170
# [libx264 @ 0x12b005d60] consecutive B-frames: 15.8% 12.2%  4.0% 68.0%
# [libx264 @ 0x12b005d60] mb I  I16..4: 36.7% 52.3% 11.0%
# [libx264 @ 0x12b005d60] mb P  I16..4:  0.5%  0.9%  0.1%  P16..4:  2.3%  0.4%  0.3%  0.0%  0.0%    skip:95.5%
# [libx264 @ 0x12b005d60] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.5%  0.1%  0.0%  direct: 0.1%  skip:98.2%  L0:49.2% L1:48.8% BI: 2.0%
# [libx264 @ 0x12b005d60] 8x8 transform intra:56.4% inter:21.6%
# [libx264 @ 0x12b005d60] coded y,uvDC,uvAC intra: 6.8% 6.9% 3.6% inter: 0.4% 0.2% 0.0%
# [libx264 @ 0x12b005d60] i16 v,h,dc,p: 86% 10%  4%  0%
# [libx264 @ 0x12b005d60] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 52% 15% 32%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x12b005d60] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 44% 19% 18%  3%  3%  3%  3%  3%  2%
# [libx264 @ 0x12b005d60] i8c dc,h,v,p: 81%  3% 16%  0%
# [libx264 @ 0x12b005d60] Weighted P-Frames: Y:4.2% UV:2.8%
# [libx264 @ 0x12b005d60] ref P L0: 63.7% 12.2% 16.4%  7.3%  0.3%
# [libx264 @ 0x12b005d60] ref B L0: 52.0% 46.5%  1.5%
# [libx264 @ 0x12b005d60] ref B L1: 98.3%  1.7%
# [libx264 @ 0x12b005d60] kb/s:134.39
# [aac @ 0x12b007040] Qavg: 4711.507
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x154e381f0] using SAR=1/1
# [libx264 @ 0x154e381f0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x154e381f0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x154e381f0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_6/video_6.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=582 q=-1.0 Lsize=     817kB time=00:00:29.97 bitrate= 223.3kbits/s speed=19.4x
# video:316kB audio:468kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.213676%
# [libx264 @ 0x154e381f0] frame I:4     Avg QP:15.51  size: 21804
# [libx264 @ 0x154e381f0] frame P:275   Avg QP:17.41  size:   582
# [libx264 @ 0x154e381f0] frame B:621   Avg QP:18.15  size:   122
# [libx264 @ 0x154e381f0] consecutive B-frames:  4.8%  7.1%  7.7% 80.4%
# [libx264 @ 0x154e381f0] mb I  I16..4: 39.8% 45.6% 14.6%
# [libx264 @ 0x154e381f0] mb P  I16..4:  0.8%  0.1%  0.1%  P16..4:  0.8%  0.3%  0.2%  0.0%  0.0%    skip:97.8%
# [libx264 @ 0x154e381f0] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  1.1%  0.1%  0.0%  direct: 0.0%  skip:98.7%  L0:47.7% L1:49.2% BI: 3.1%
# [libx264 @ 0x154e381f0] 8x8 transform intra:30.4% inter:27.0%
# [libx264 @ 0x154e381f0] coded y,uvDC,uvAC intra: 9.0% 8.7% 4.9% inter: 0.2% 0.1% 0.0%
# [libx264 @ 0x154e381f0] i16 v,h,dc,p: 95%  2%  3%  0%
# [libx264 @ 0x154e381f0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 61%  3% 35%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x154e381f0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 54% 13% 18%  3%  2%  3%  2%  4%  2%
# [libx264 @ 0x154e381f0] i8c dc,h,v,p: 63%  2% 33%  1%
# [libx264 @ 0x154e381f0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x154e381f0] ref P L0: 73.6%  9.1% 11.1%  6.3%
# [libx264 @ 0x154e381f0] ref B L0: 63.8% 33.4%  2.8%
# [libx264 @ 0x154e381f0] ref B L1: 97.8%  2.2%
# [libx264 @ 0x154e381f0] kb/s:86.12
# [aac @ 0x154e394d0] Qavg: 660.254
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-04T17:54:12.000000Z
#   Duration: 00:20:45.80, start: 0.000000, bitrate: 222 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 90 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13be37880] using SAR=1/1
# [libx264 @ 0x13be37880] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13be37880] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x13be37880] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Mathematics_Calculus_Integration_and_the_fundamental_theorem_of_calculus/video_7/video_7.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-04T17:54:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/04/2018.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  901 fps=514 q=-1.0 Lsize=     926kB time=00:00:29.97 bitrate= 253.1kbits/s dup=1 drop=0 speed=17.1x
# video:426kB audio:468kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.666473%
# [libx264 @ 0x13be37880] frame I:4     Avg QP:15.17  size: 26606
# [libx264 @ 0x13be37880] frame P:304   Avg QP:17.55  size:   856
# [libx264 @ 0x13be37880] frame B:593   Avg QP:15.98  size:   115
# [libx264 @ 0x13be37880] consecutive B-frames:  9.3%  6.9%  5.7% 78.1%
# [libx264 @ 0x13be37880] mb I  I16..4: 37.9% 44.9% 17.2%
# [libx264 @ 0x13be37880] mb P  I16..4:  2.0%  0.2%  0.2%  P16..4:  1.3%  0.3%  0.2%  0.0%  0.0%    skip:95.6%
# [libx264 @ 0x13be37880] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  1.3%  0.1%  0.0%  direct: 0.0%  skip:98.5%  L0:49.3% L1:49.3% BI: 1.3%
# [libx264 @ 0x13be37880] 8x8 transform intra:21.7% inter:31.1%
# [libx264 @ 0x13be37880] coded y,uvDC,uvAC intra: 10.6% 15.1% 4.1% inter: 0.2% 0.2% 0.1%
# [libx264 @ 0x13be37880] i16 v,h,dc,p: 95%  3%  2%  0%
# [libx264 @ 0x13be37880] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 63%  5% 31%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x13be37880] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 60% 11% 16%  2%  2%  2%  2%  3%  2%
# [libx264 @ 0x13be37880] i8c dc,h,v,p: 58%  5% 36%  1%
# [libx264 @ 0x13be37880] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13be37880] ref P L0: 83.7%  8.2%  6.0%  2.1%
# [libx264 @ 0x13be37880] ref B L0: 65.5% 33.2%  1.3%
# [libx264 @ 0x13be37880] ref B L1: 97.4%  2.6%
# [libx264 @ 0x13be37880] kb/s:115.77
# [aac @ 0x13be38b60] Qavg: 476.622
# ...
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x140708980] using SAR=1/1
# [libx264 @ 0x140708980] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x140708980] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x140708980] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Cars_SnowDrivingTips_Everything_You_Need_To_Know_About_Driving_In_The_Snow/video_2/video_2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=155 q=-1.0 Lsize=    7523kB time=00:00:29.97 bitrate=2055.8kbits/s speed=5.18x
# video:7022kB audio:468kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.434066%
# [libx264 @ 0x140708980] frame I:4     Avg QP:21.00  size: 43558
# [libx264 @ 0x140708980] frame P:288   Avg QP:22.61  size: 13613
# [libx264 @ 0x140708980] frame B:608   Avg QP:25.51  size:  5091
# [libx264 @ 0x140708980] consecutive B-frames:  0.7% 15.8% 36.0% 47.6%
# [libx264 @ 0x140708980] mb I  I16..4: 17.9% 58.4% 23.8%
# [libx264 @ 0x140708980] mb P  I16..4:  6.6% 12.0%  1.7%  P16..4: 34.3% 11.5%  3.6%  0.0%  0.0%    skip:30.3%
# [libx264 @ 0x140708980] mb B  I16..4:  0.6%  0.9%  0.1%  B16..8: 37.3%  5.8%  0.6%  direct: 1.5%  skip:53.1%  L0:46.2% L1:50.4% BI: 3.3%
# [libx264 @ 0x140708980] 8x8 transform intra:58.9% inter:68.1%
# [libx264 @ 0x140708980] coded y,uvDC,uvAC intra: 37.5% 18.2% 1.3% inter: 11.0% 3.8% 0.1%
# [libx264 @ 0x140708980] i16 v,h,dc,p: 23% 41% 15% 21%
# [libx264 @ 0x140708980] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 22% 34%  3%  5%  4%  7%  3%  6%
# [libx264 @ 0x140708980] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 26% 22%  4%  8%  5%  8%  3%  5%
# [libx264 @ 0x140708980] i8c dc,h,v,p: 69% 21%  9%  1%
# [libx264 @ 0x140708980] Weighted P-Frames: Y:2.8% UV:2.4%
# [libx264 @ 0x140708980] ref P L0: 65.4% 14.3% 13.7%  6.3%  0.2%
# [libx264 @ 0x140708980] ref B L0: 88.2%  9.6%  2.2%
# [libx264 @ 0x140708980] ref B L1: 97.9%  2.1%
# [libx264 @ 0x140708980] kb/s:1915.47
# [aac @ 0x140709c60] Qavg: 477.984
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Cars_SnowDrivingTips_Everything_You_Need_To_Know_About_Driving_In_The_Snow.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-12-01T02:16:42.000000Z
#   Duration: 00:05:13.59, start: 0.000000, bitrate: 2169 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 2037 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x158635160] using SAR=1/1
# [libx264 @ 0x158635160] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x158635160] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x158635160] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Cars_SnowDrivingTips_Everything_You_Need_To_Know_About_Driving_In_The_Snow/video_3/video_3.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  901 fps=133 q=-1.0 Lsize=   10932kB time=00:00:29.97 bitrate=2987.4kbits/s dup=1 drop=0 speed=4.42x
# video:10430kB audio:469kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.303514%
# [libx264 @ 0x158635160] frame I:5     Avg QP:21.11  size: 52323
# [libx264 @ 0x158635160] frame P:258   Avg QP:24.02  size: 19441
# [libx264 @ 0x158635160] frame B:638   Avg QP:26.56  size:  8467
# [libx264 @ 0x158635160] consecutive B-frames:  2.0%  7.5%  9.7% 80.8%
# [libx264 @ 0x158635160] mb I  I16..4: 19.9% 58.3% 21.8%
# [libx264 @ 0x158635160] mb P  I16..4:  9.4% 21.5%  2.3%  P16..4: 30.3% 11.4%  5.2%  0.0%  0.0%    skip:19.9%
# [libx264 @ 0x158635160] mb B  I16..4:  2.1%  5.0%  0.4%  B16..8: 34.2%  8.7%  1.5%  direct: 2.9%  skip:45.1%  L0:46.7% L1:46.8% BI: 6.4%
# [libx264 @ 0x158635160] 8x8 transform intra:64.9% inter:69.3%
# [libx264 @ 0x158635160] coded y,uvDC,uvAC intra: 46.0% 20.8% 1.4% inter: 16.1% 6.4% 0.3%
# [libx264 @ 0x158635160] i16 v,h,dc,p: 17% 42% 13% 28%
# [libx264 @ 0x158635160] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 28% 25%  4%  5%  4%  6%  4%  7%
# [libx264 @ 0x158635160] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 29% 19%  5%  7%  5%  8%  4%  5%
# [libx264 @ 0x158635160] i8c dc,h,v,p: 72% 17%  9%  1%
# [libx264 @ 0x158635160] Weighted P-Frames: Y:9.3% UV:5.8%
# [libx264 @ 0x158635160] ref P L0: 56.2% 17.1% 17.6%  8.6%  0.5%
# [libx264 @ 0x158635160] ref B L0: 80.3% 15.0%  4.7%
# [libx264 @ 0x158635160] ref B L1: 94.3%  5.7%
# [libx264 @ 0x158635160] kb/s:2841.79
# [aac @ 0x158636390] Qavg: 645.117
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/videos/playlist_Cars_SnowDrivingTips_Everything_You_Need_To_Know_About_Driving_In_The_Snow.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-12-01T02:16:42.000000Z
#   Duration: 00:05:13.59, start: 0.000000, bitrate: 2169 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 2037 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13e6051d0] using SAR=1/1
# [libx264 @ 0x13e6051d0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13e6051d0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x13e6051d0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../data/clips/playlist_Cars_SnowDrivingTips_Everything_You_Need_To_Know_About_Driving_In_The_Snow/video_4/video_4.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-12-01T02:16:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/30/2019.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 aac
# frame=  900 fps=125 q=-1.0 Lsize=   14151kB time=00:00:29.97 bitrate=3867.2kbits/s speed=4.17x
# video:13649kB audio:469kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.232999%
# [libx264 @ 0x13e6051d0] frame I:4     Avg QP:22.09  size: 72199
# [libx264 @ 0x13e6051d0] frame P:300   Avg QP:24.97  size: 28257
# [libx264 @ 0x13e6051d0] frame B:596   Avg QP:27.97  size:  8741
# [libx264 @ 0x13e6051d0] consecutive B-frames:  0.7% 26.4% 20.0% 52.9%
# [libx264 @ 0x13e6051d0] mb I  I16..4: 12.1% 64.2% 23.6%
# [libx264 @ 0x13e6051d0] mb P  I16..4:  4.8% 13.1%  3.3%  P16..4: 35.5% 17.3%  9.0%  0.0%  0.0%    skip:17.0%
# [libx264 @ 0x13e6051d0] mb B  I16..4:  0.7%  2.0%  0.4%  B16..8: 39.2%  8.8%  2.1%  direct: 2.7%  skip:44.1%  L0:41.9% L1:47.5% BI:10.6%
# [libx264 @ 0x13e6051d0] 8x8 transform intra:62.3% inter:48.4%
# [libx264 @ 0x13e6051d0] coded y,uvDC,uvAC intra: 54.5% 21.8% 0.8% inter: 17.7% 4.6% 0.0%
# [libx264 @ 0x13e6051d0] i16 v,h,dc,p: 19% 29% 15% 37%
# [libx264 @ 0x13e6051d0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 22% 25%  5%  7%  5%  8%  4%  7%
# [libx264 @ 0x13e6051d0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 19% 22%  6% 10%  6% 10%  5%  7%
# [libx264 @ 0x13e6051d0] i8c dc,h,v,p: 76% 14%  9%  1%
# [libx264 @ 0x13e6051d0] Weighted P-Frames: Y:6.0% UV:4.0%
# [libx264 @ 0x13e6051d0] ref P L0: 63.1% 20.7% 11.2%  4.8%  0.1%
# [libx264 @ 0x13e6051d0] ref B L0: 87.8% 10.2%  2.0%
# [libx264 @ 0x13e6051d0] ref B L1: 97.8%  2.2%
# [libx264 @ 0x13e6051d0] kb/s:3723.16
# [aac @ 0x13e606490] Qavg: 616.575
