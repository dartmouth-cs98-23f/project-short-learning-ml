# %%
import torch
import os

# https://www.youtube.com/watch?v=E5kzAbD8D0w, DPO
# https://www.youtube.com/watch?v=wybjsKtA9hI, SQL Backend
# https://www.youtube.com/watch?v=CZw57SIwgiE, Threads and Connections
# https://www.youtube.com/watch?v=p6wwj0ozifw, Hashing
# https://www.youtube.com/watch?v=4NB0NDtOwIQ, sys_design
# https://www.youtube.com/watch?v=kxT8-C1vmd4, zig
# https://www.youtube.com/watch?v=5C_HPTJg5ek, rust
# https://www.youtube.com/watch?v=HyWYpM_S-2c, React
# https://www.youtube.com/watch?v=MnpuK0MK4yo, react_svelte
# https://www.youtube.com/watch?v=mE7IDf2SmJg, stanford_lecture_rag
# https://www.youtube.com/watch?v=utYC2tKDdoQ, umich_os_locks
# https://www.youtube.com/watch?v=YAgjfMR9R_M, umich_dl_attention
# https://www.youtube.com/watch?v=dsHyUgGMht0, k_fang_github_break 


videos = [
    ["https://www.youtube.com/watch?v=UiX8K-xBUpE", "UiX8K-xBUpE", "mixtral8x7b"],
    ["https://www.youtube.com/watch?v=Xdhe-meS30A", "Xdhe-meS30A", "catan"],
    ["https://www.youtube.com/watch?v=00AQjBDM46Q", "00AQjBDM46Q", "mlops_llm_eval"],
    ["https://www.youtube.com/watch?v=5ChkQKUzDCs", "5ChkQKUzDCs", "typescript_fireship"],
    ["https://www.youtube.com/watch?v=J0NuOlA2xDc", "J0NuOlA2xDc", "localized_deployment"],
    ["https://www.youtube.com/watch?v=E5kzAbD8D0w", "E5kzAbD8D0w", "dpo"],
    ["https://www.youtube.com/watch?v=wybjsKtA9hI", "wybjsKtA9hI", "sql_backend"],
    ["https://www.youtube.com/watch?v=CZw57SIwgiE", "CZw57SIwgiE", "threads_connections"],
    ["https://www.youtube.com/watch?v=p6wwj0ozifw", "p6wwj0ozifw", "hashing"],
    # ["https://www.youtube.com/watch?v=4NB0NDtOwIQ", "4NB0NDtOwIQ", "sys_design"], // Note this failed due to not having a timestamp every line
    ["https://www.youtube.com/watch?v=kxT8-C1vmd4", "kxT8-C1vmd4", "zig"],
    ["https://www.youtube.com/watch?v=5C_HPTJg5ek", "5C_HPTJg5ek", "rust"],
    ["https://www.youtube.com/watch?v=HyWYpM_S-2c", "HyWYpM_S-2c", "react"],
    ["https://www.youtube.com/watch?v=MnpuK0MK4yo", "MnpuK0MK4yo", "react_svelte"],
]

name_to_url = {
    "mixtral8x7b": "https://www.youtube.com/watch?v=UiX8K-xBUpE",
    "catan": "https://www.youtube.com/watch?v=Xdhe-meS30A",
    "mlops_llm_eval": "https://www.youtube.com/watch?v=00AQjBDM46Q",
    "typescript_fireship": "https://www.youtube.com/watch?v=5ChkQKUzDCs",
    "localized_deployment": "https://www.youtube.com/watch?v=J0NuOlA2xDc",
    "dpo": "https://www.youtube.com/watch?v=E5kzAbD8D0w",
    "sql_backend": "https://www.youtube.com/watch?v=wybjsKtA9hI",
    "threads_connections": "https://www.youtube.com/watch?v=CZw57SIwgiE",
    "hashing": "https://www.youtube.com/watch?v=p6wwj0ozifw",
    "zig": "https://www.youtube.com/watch?v=kxT8-C1vmd4",
    "rust": "https://www.youtube.com/watch?v=5C_HPTJg5ek",
    "react": "https://www.youtube.com/watch?v=HyWYpM_S-2c",
    "react_svelte": "https://www.youtube.com/watch?v=MnpuK0MK4yo",
}

# %%
from pinecone import Pinecone

pc = Pinecone(api_key="")
index = pc.Index("inftest")

# %%
vectors = []
for embedding_file in os.listdir('data/embeddings'):
    if not embedding_file.endswith('.pt'):
        continue
    name = embedding_file[:-3]
    metadata = {"name": name, "url": name_to_url[name]}
    tensor = torch.load(f'data/embeddings/{embedding_file}')
    # max_pooled = torch.max(tensor, 1).squeeze(0)
    avg_pooled = torch.mean(tensor, 1).squeeze(0)
    vectors.append({"values": avg_pooled.numpy().tolist(), "id": name, "metadata": metadata})

# %%
index.upsert(vectors=vectors)
# Out:
# {'upserted_count': 13}

# %%
for embedding_file in os.listdir('data/embeddings'):
    if not embedding_file.endswith('.pt'):
        continue
    name = embedding_file[:-3]
    # Tensor is shape[1, 968, 4096]
    tensor = torch.load(f'data/embeddings/{embedding_file}')
    max_pooled = torch.max(tensor, 1)
    average_pool = torch.mean(tensor, 1)
    query = average_pool.squeeze(0).numpy().tolist()
    response = index.query(vector=query, top_k=5, include_values=True, include_metadata=True)
    print(f'Querying {name}:')
    for i, obj in enumerate(response["matches"]):
        print(f'    Rank: {i+1}, Metadata: {obj["metadata"]}, Distance:, Score: {obj["score"]}')
# Out:
# Querying mixtral8x7b:
#     Rank: 1, Metadata: {'name': 'mixtral8x7b', 'url': 'https://www.youtube.com/watch?v=UiX8K-xBUpE'}, Distance:, Score: -0.0111542046
#     Rank: 2, Metadata: {'name': 'hashing', 'url': 'https://www.youtube.com/watch?v=p6wwj0ozifw'}, Distance:, Score: -0.0617989302
#     Rank: 3, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: -0.0630171373
#     Rank: 4, Metadata: {'name': 'threads_connections', 'url': 'https://www.youtube.com/watch?v=CZw57SIwgiE'}, Distance:, Score: -0.0834558606
#     Rank: 5, Metadata: {'name': 'dpo', 'url': 'https://www.youtube.com/watch?v=E5kzAbD8D0w'}, Distance:, Score: -0.0906992629
# Querying sql_backend:
#     Rank: 1, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: -0.0241921432
#     Rank: 2, Metadata: {'name': 'hashing', 'url': 'https://www.youtube.com/watch?v=p6wwj0ozifw'}, Distance:, Score: -0.0396162271
#     Rank: 3, Metadata: {'name': 'mixtral8x7b', 'url': 'https://www.youtube.com/watch?v=UiX8K-xBUpE'}, Distance:, Score: -0.0508686863
#     Rank: 4, Metadata: {'name': 'threads_connections', 'url': 'https://www.youtube.com/watch?v=CZw57SIwgiE'}, Distance:, Score: -0.0680538341
#     Rank: 5, Metadata: {'name': 'dpo', 'url': 'https://www.youtube.com/watch?v=E5kzAbD8D0w'}, Distance:, Score: -0.099795185
# Querying dpo:
#     Rank: 1, Metadata: {'name': 'dpo', 'url': 'https://www.youtube.com/watch?v=E5kzAbD8D0w'}, Distance:, Score: 1.00753093
#     Rank: 2, Metadata: {'name': 'mixtral8x7b', 'url': 'https://www.youtube.com/watch?v=UiX8K-xBUpE'}, Distance:, Score: 0.881889462
#     Rank: 3, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: 0.857811749
#     Rank: 4, Metadata: {'name': 'mlops_llm_eval', 'url': 'https://www.youtube.com/watch?v=00AQjBDM46Q'}, Distance:, Score: 0.852005124
#     Rank: 5, Metadata: {'name': 'typescript_fireship', 'url': 'https://www.youtube.com/watch?v=5ChkQKUzDCs'}, Distance:, Score: 0.851306617
# Querying hashing:
#     Rank: 1, Metadata: {'name': 'hashing', 'url': 'https://www.youtube.com/watch?v=p6wwj0ozifw'}, Distance:, Score: 1.00039315
#     Rank: 2, Metadata: {'name': 'threads_connections', 'url': 'https://www.youtube.com/watch?v=CZw57SIwgiE'}, Distance:, Score: 0.915407717
#     Rank: 3, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: 0.858258426
#     Rank: 4, Metadata: {'name': 'rust', 'url': 'https://www.youtube.com/watch?v=5C_HPTJg5ek'}, Distance:, Score: 0.826335847
#     Rank: 5, Metadata: {'name': 'react', 'url': 'https://www.youtube.com/watch?v=HyWYpM_S-2c'}, Distance:, Score: 0.794528484
# Querying zig:
#     Rank: 1, Metadata: {'name': 'zig', 'url': 'https://www.youtube.com/watch?v=kxT8-C1vmd4'}, Distance:, Score: 1.00499725
#     Rank: 2, Metadata: {'name': 'react_svelte', 'url': 'https://www.youtube.com/watch?v=MnpuK0MK4yo'}, Distance:, Score: 0.884236634
#     Rank: 3, Metadata: {'name': 'rust', 'url': 'https://www.youtube.com/watch?v=5C_HPTJg5ek'}, Distance:, Score: 0.859186172
#     Rank: 4, Metadata: {'name': 'typescript_fireship', 'url': 'https://www.youtube.com/watch?v=5ChkQKUzDCs'}, Distance:, Score: 0.853526592
#     Rank: 5, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: 0.846431
# Querying rust:
#     Rank: 1, Metadata: {'name': 'rust', 'url': 'https://www.youtube.com/watch?v=5C_HPTJg5ek'}, Distance:, Score: 1.00217736
#     Rank: 2, Metadata: {'name': 'zig', 'url': 'https://www.youtube.com/watch?v=kxT8-C1vmd4'}, Distance:, Score: 0.859186172
#     Rank: 3, Metadata: {'name': 'threads_connections', 'url': 'https://www.youtube.com/watch?v=CZw57SIwgiE'}, Distance:, Score: 0.832862437
#     Rank: 4, Metadata: {'name': 'hashing', 'url': 'https://www.youtube.com/watch?v=p6wwj0ozifw'}, Distance:, Score: 0.826335847
#     Rank: 5, Metadata: {'name': 'react', 'url': 'https://www.youtube.com/watch?v=HyWYpM_S-2c'}, Distance:, Score: 0.825409651
# Querying react:
#     Rank: 1, Metadata: {'name': 'react', 'url': 'https://www.youtube.com/watch?v=HyWYpM_S-2c'}, Distance:, Score: 1.0027771
#     Rank: 2, Metadata: {'name': 'rust', 'url': 'https://www.youtube.com/watch?v=5C_HPTJg5ek'}, Distance:, Score: 0.825409591
#     Rank: 3, Metadata: {'name': 'react_svelte', 'url': 'https://www.youtube.com/watch?v=MnpuK0MK4yo'}, Distance:, Score: 0.81776458
#     Rank: 4, Metadata: {'name': 'threads_connections', 'url': 'https://www.youtube.com/watch?v=CZw57SIwgiE'}, Distance:, Score: 0.810614645
#     Rank: 5, Metadata: {'name': 'typescript_fireship', 'url': 'https://www.youtube.com/watch?v=5ChkQKUzDCs'}, Distance:, Score: 0.801979721
# Querying catan:
#     Rank: 1, Metadata: {'name': 'catan', 'url': 'https://www.youtube.com/watch?v=Xdhe-meS30A'}, Distance:, Score: 1.00398993
#     Rank: 2, Metadata: {'name': 'mlops_llm_eval', 'url': 'https://www.youtube.com/watch?v=00AQjBDM46Q'}, Distance:, Score: 0.839545429
#     Rank: 3, Metadata: {'name': 'typescript_fireship', 'url': 'https://www.youtube.com/watch?v=5ChkQKUzDCs'}, Distance:, Score: 0.833969772
#     Rank: 4, Metadata: {'name': 'dpo', 'url': 'https://www.youtube.com/watch?v=E5kzAbD8D0w'}, Distance:, Score: 0.829443812
#     Rank: 5, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: 0.819316208
# Querying mlops_llm_eval:
#     Rank: 1, Metadata: {'name': 'mlops_llm_eval', 'url': 'https://www.youtube.com/watch?v=00AQjBDM46Q'}, Distance:, Score: 1.00297737
#     Rank: 2, Metadata: {'name': 'typescript_fireship', 'url': 'https://www.youtube.com/watch?v=5ChkQKUzDCs'}, Distance:, Score: 0.874753356
#     Rank: 3, Metadata: {'name': 'dpo', 'url': 'https://www.youtube.com/watch?v=E5kzAbD8D0w'}, Distance:, Score: 0.852005124
#     Rank: 4, Metadata: {'name': 'mixtral8x7b', 'url': 'https://www.youtube.com/watch?v=UiX8K-xBUpE'}, Distance:, Score: 0.845663965
#     Rank: 5, Metadata: {'name': 'catan', 'url': 'https://www.youtube.com/watch?v=Xdhe-meS30A'}, Distance:, Score: 0.839545369
# Querying localized_deployment:
#     Rank: 1, Metadata: {'name': 'localized_deployment', 'url': 'https://www.youtube.com/watch?v=J0NuOlA2xDc'}, Distance:, Score: 1.00096095
#     Rank: 2, Metadata: {'name': 'react_svelte', 'url': 'https://www.youtube.com/watch?v=MnpuK0MK4yo'}, Distance:, Score: 0.521874547
#     Rank: 3, Metadata: {'name': 'zig', 'url': 'https://www.youtube.com/watch?v=kxT8-C1vmd4'}, Distance:, Score: 0.48573035
#     Rank: 4, Metadata: {'name': 'react', 'url': 'https://www.youtube.com/watch?v=HyWYpM_S-2c'}, Distance:, Score: 0.482369393
#     Rank: 5, Metadata: {'name': 'rust', 'url': 'https://www.youtube.com/watch?v=5C_HPTJg5ek'}, Distance:, Score: 0.476242334
# Querying threads_connections:
#     Rank: 1, Metadata: {'name': 'threads_connections', 'url': 'https://www.youtube.com/watch?v=CZw57SIwgiE'}, Distance:, Score: 1.00034928
#     Rank: 2, Metadata: {'name': 'hashing', 'url': 'https://www.youtube.com/watch?v=p6wwj0ozifw'}, Distance:, Score: 0.915407717
#     Rank: 3, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: 0.832948208
#     Rank: 4, Metadata: {'name': 'rust', 'url': 'https://www.youtube.com/watch?v=5C_HPTJg5ek'}, Distance:, Score: 0.832862496
#     Rank: 5, Metadata: {'name': 'react', 'url': 'https://www.youtube.com/watch?v=HyWYpM_S-2c'}, Distance:, Score: 0.810614645
# Querying typescript_fireship:
#     Rank: 1, Metadata: {'name': 'typescript_fireship', 'url': 'https://www.youtube.com/watch?v=5ChkQKUzDCs'}, Distance:, Score: 1.00326622
#     Rank: 2, Metadata: {'name': 'react_svelte', 'url': 'https://www.youtube.com/watch?v=MnpuK0MK4yo'}, Distance:, Score: 0.892023206
#     Rank: 3, Metadata: {'name': 'mlops_llm_eval', 'url': 'https://www.youtube.com/watch?v=00AQjBDM46Q'}, Distance:, Score: 0.874753356
#     Rank: 4, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: 0.857265651
#     Rank: 5, Metadata: {'name': 'zig', 'url': 'https://www.youtube.com/watch?v=kxT8-C1vmd4'}, Distance:, Score: 0.853526592
# Querying react_svelte:
#     Rank: 1, Metadata: {'name': 'react_svelte', 'url': 'https://www.youtube.com/watch?v=MnpuK0MK4yo'}, Distance:, Score: 1.00557792
#     Rank: 2, Metadata: {'name': 'typescript_fireship', 'url': 'https://www.youtube.com/watch?v=5ChkQKUzDCs'}, Distance:, Score: 0.892023325
#     Rank: 3, Metadata: {'name': 'zig', 'url': 'https://www.youtube.com/watch?v=kxT8-C1vmd4'}, Distance:, Score: 0.884236574
#     Rank: 4, Metadata: {'name': 'sql_backend', 'url': 'https://www.youtube.com/watch?v=wybjsKtA9hI'}, Distance:, Score: 0.834773481
#     Rank: 5, Metadata: {'name': 'react', 'url': 'https://www.youtube.com/watch?v=HyWYpM_S-2c'}, Distance:, Score: 0.817764521
